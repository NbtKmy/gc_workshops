# %% [markdown]
# <a href="https://colab.research.google.com/github/NbtKmy/gc_workshops/blob/main/Word2Vec.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Vektorisierung oder Embedding
#
# Die Vektorisierung bei NLP bedeutet, dass man die Elemente in einem Textkorpus wie Wörter, Sätze und Texte in Vektor-Werte umwandelt. Durch Vektorisierung können die Ähnlichkeit oder Distanz zwischen Wörter, Sätze oder Texte "berechnet" werden.
#
# Vektorisierung von Wörter, Sätze oder Texte werden auch Word-, Sentence- oder Text-Embedding bezeichnet.
#
# In diesem Beispiel probieren wir die Word-Embedding.
# Für dieses Verfahren verwenden wir die Library "[gensim](https://radimrehurek.com/gensim/)".
#
# Als Beispiel nehmen wir den Roman "Frankenstein" von Shelley.
#
# Der ganze Prozess verläuft so:
#
# 1. Preprozess - Der gesamte Text wird in 2-dimensionalen Array umgewandelt. Dabei wird Satz-Einheit berücksichtigt. Darüber hinaus werden nur bestimmte POS für die Vektorisierung herausgenommen.
#
# 1. Vektorisierung mit Word2Vec.

# %%
# !pip install -q spacy gensim spacy[transformers]
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.8/190.8 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 15.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 27.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 21.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 41.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.7 MB/s eta 0:00:00

# %%
from spacy.cli import download
download("en_core_web_trf")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_trf')

# %% [markdown]
# ## Preprozess
#
#
# Um den ganzen Roman zu bearbeiten, dauert es ca. 11 min...
# Bei der Tokenisierung wurde hier alle Wörter lemmatisiert, obwohl einige Entitäten wie "St. Petersburt" usw. aus mehr als ein Wort bestehen.
# Hier wurde solche Fälle einfachhalber so belassen. Aber bei der Forschung wäre wichtig, solche Entitäten zu berücksichtigen.

# %%
# %%time
from spacy.lang.en import English
import spacy
import spacy_transformers

nlp_sent = English()
nlp_sent.add_pipe("sentencizer")

# Text-Daten einlesen
with open("frankenstein_full.txt") as f:
	  text = f.read()


doc = nlp_sent(text)


positiv_index = ["ADJ", "ADV", "NOUN", "PROPN", "VERB", "X"]

nlp = spacy.load("en_core_web_trf")

full_arr = []
for s in doc.sents:
    s = str(s)
    sent_analyse = nlp(s)
    sent_arr = []
    for token in sent_analyse:
        if token.pos_ in positiv_index:
            sent_arr.append(token.lemma_)
    if len(sent_arr) != 0:
        full_arr.append(sent_arr)

print(full_arr)
# Out:
# [['letter', 'Mrs.', 'Seville', 'England', 'St.', 'Petersburgh', 'Dec.', '11th', 'rejoice', 'hear', 'disaster', 'accompany', 'commencement', 'enterprise', 'regard', 'such', 'evil', 'foreboding'], ['arrive', 'here', 'yesterday', 'first', 'task', 'assure', 'dear', 'sister', 'welfare', 'increase', 'confidence', 'success', 'undertaking'], ['already', 'far', 'north', 'London', 'walk', 'street', 'Petersburgh', 'feel', 'cold', 'northern', 'breeze', 'play', 'cheek', 'brace', 'nerve', 'fill', 'delight'], ['understand', 'feeling'], ['breeze', 'travel', 'region', 'advance', 'give', 'foretaste', 'icy', 'clime'], ['inspirit', 'wind', 'promise', 'daydream', 'become', 'more', 'fervent', 'vivid'], ['try', 'vain', 'persuade', 'pole', 'seat', 'frost', 'desolation', 'ever', 'present', 'imagination', 'region', 'beauty', 'delight'], ['there', 'Margaret', 'sun', 'forever', 'visible', 'broad', 'disk', 'just', 'skirt', 'horizon', 'diffuse', 'perpetual', 'splendour'], ['there', 'leave', 'sister', 'put', 'trust', 'precede', 'navigator', 'there', 'snow', 'frost', 'banish', 'sail', 'calm', 'sea', 'waft', 'land', 'surpass', 'wonder', 'beauty', 'region', 'hitherto', 'discover', 'habitable', 'globe'], ['production', 'feature', 'example', 'phenomenon', 'heavenly', 'body', 'undoubtedly', 'undiscovered', 'solitude'], ['expect', 'country', 'eternal', 'light'], ['there', 'discover', 'wondrous', 'power', 'attract', 'needle', 'regulate', 'celestial', 'observation', 'require', 'only', 'voyage', 'render', 'seeming', 'eccentricity', 'consistent', 'forever'], ['satiate', 'ardent', 'curiosity', 'sight', 'part', 'world', 'never', 'before', 'visit', 'tread', 'land', 'never', 'before', 'imprint', 'foot', 'man'], ['enticement', 'sufficient', 'conquer', 'fear', 'danger', 'death', 'induce', 'commence', 'laborious', 'voyage', 'joy', 'child', 'feel', 'embark', 'little', 'boat', 'holiday', 'mate', 'expedition', 'discovery', 'native', 'river'], ['suppose', 'conjecture', 'false', 'contest', 'inestimable', 'benefit', 'confer', 'mankind', 'last', 'generation', 'discover', 'passage', 'pole', 'country', 'reach', 'present', 'so', 'many', 'month', 'requisite', 'ascertain', 'secret', 'magnet', 'at', 'all', 'possible', 'only', 'effect', 'undertaking', 'such', 'mine'], ['reflection', 'dispel', 'agitation', 'begin', 'letter', 'feel', 'heart', 'glow', 'enthusiasm', 'elevate', 'heaven', 'contribute', 'so', 'much', 'tranquillize', 'mind', 'steady', 'purpose', 'point', 'soul', 'fix', 'intellectual', 'eye'], ['expedition', 'favourite', 'dream', 'early', 'year'], ['read', 'ardour', 'account', 'various', 'voyage', 'make', 'prospect', 'arrive', 'North', 'Pacific', 'Ocean', 'sea', 'surround', 'pole'], ['remember', 'history', 'voyage', 'make', 'purpose', 'discovery', 'compose', 'whole', 'good', 'Uncle', 'Thomas', 'library'], ['education', 'neglect', 'passionately', 'fond', 'reading'], ['volume', 'study', 'day', 'night', 'familiarity', 'increase', 'regret', 'feel', 'child', 'learn', 'father', 'die', 'injunction', 'forbid', 'uncle', 'allow', 'embark', 'seafaring', 'life'], ['vision', 'fade', 'peruse', 'first', 'time', 'poet', 'effusion', 'entrance', 'soul', 'lift', 'heaven'], ['also', 'become', 'poet', 'year', 'live', 'paradise', 'own', 'creation', 'imagine', 'also', 'obtain', 'niche', 'temple', 'name', 'Homer', 'Shakespeare', 'consecrate'], ['well', 'acquainted', 'failure', 'heavily', 'bear', 'disappointment'], ['just', 'time', 'inherit', 'fortune', 'cousin', 'thought', 'turn', 'channel', 'early', 'bent'], ['year', 'pass', 'resolve', 'present', 'undertaking'], ['even', 'now', 'remember', 'hour', 'dedicate', 'great', 'enterprise'], ['commence', 'inure', 'body', 'hardship'], ['accompany', 'whale', 'fisher', 'several', 'expedition', 'North', 'Sea', 'voluntarily', 'endure', 'cold', 'famine', 'thirst', 'want', 'sleep', 'often', 'work', 'hard', 'common', 'sailor', 'day', 'devote', 'night', 'study', 'mathematic', 'theory', 'medicine', 'branch', 'physical', 'science', 'naval', 'adventurer', 'derive', 'great', ...
# CPU times: user 10min 54s, sys: 3.6 s, total: 10min 58s
# Wall time: 11min 15s

# %%
from gensim.models import word2vec

model = word2vec.Word2Vec(
            full_arr,
            vector_size=300,
            window=5,
            min_count=3,
            sg=1)

model.save("./w2v.model")
model.wv.save_word2vec_format("./frankenstein_w2v.pt", binary=True)

# %%
# Wenn man das fertige Model verwenden will
# Zuerst die "model"-File hochladen

import gensim

# Load pre-trained Word2Vec model.
model = gensim.models.Word2Vec.load("frankenstein_w2v.model")
print(model.wv.most_similar("Frankenstein"))
# Out:
# [('tell', 0.9994692802429199), ('point', 0.9994688630104065), ('instant', 0.9994654655456543), ('afterwards', 0.9994595050811768), ('victim', 0.9994591474533081), ('wander', 0.9994535446166992), ('reflect', 0.9994466304779053), ('assure', 0.9994461536407471), ('sister', 0.9994456768035889), ('prepare', 0.9994454383850098)]

# %%
print(model.wv.most_similar("Frankenstein"))
# Out:
# [('tell', 0.9995097517967224), ('point', 0.9994792938232422), ('afterwards', 0.9994608759880066), ('instant', 0.9994537234306335), ('lose', 0.9994518160820007), ('wander', 0.9994422793388367), ('victim', 0.9994419813156128), ('try', 0.9994398951530457), ('sister', 0.999439537525177), ('reflect', 0.9994391202926636)]

# %%
# scipy und Plotly sind bereits installiert...
# !pip install -qU umap-learn scipy plotly
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 16.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for umap-learn (setup.py) ... done
#   Building wheel for pynndescent (setup.py) ... done

# %% [markdown]
# ## Visualisierung
#
# ich bedanke mich bei dem Verfasser "@hima2b4" für [diesen Artikel](https://qiita.com/hima2b4/items/23a1dfad16321c7f23ae)!

# %%
#@title UMAP
#@markdown  **<font color= "Crimson">Schritt 1</font>：Je nach dem Wert von "n_neighbors" ändert sich Clustering**

#@markdown  **<font color= "Crimson">Schritt 2</font>：Durch max_words_ratio kann man die Wörterzahl kontrollieren**

n_neighbors = 16 #@param {type:"slider", min:2, max:100, step:1}
UMAP_max_words_ratio = 0.2 #@param {type:"slider", min:0.1, max:1, step:0.05}
UMAP_text_font_size = 10 #@param {type:"slider", min:8, max:24, step:1}

import numpy as np
import pandas as pd
import umap.umap_ as umap
from scipy.sparse.csgraph import connected_components
import plotly.graph_objs as go
import plotly.express as px
import os

os.environ['OMP_NUM_THREADS'] = '1'
os.environ['PYTHONHASHSEED'] = '0'

UMAP_max_words = int(len(model.wv.vectors)*UMAP_max_words_ratio)

np.set_printoptions(suppress=True)
values1 = umap.UMAP(n_components=2,n_neighbors=n_neighbors).fit_transform(model.wv.vectors)


fig_title ='<b>UMAP on word2vec embeddings'

# Visualisierung
fig1 = go.Figure()
for value, word in zip(values1, model.wv.index_to_key[0:UMAP_max_words]):
  fig1.add_trace(
      go.Scatter(
          x = pd.Series(value[0]),
          y = pd.Series(value[1]),
          mode = 'markers+text',
          text = word,
          textposition="top center"
          )
)
fig1.update_layout(title=dict(text = fig_title,
                             font=dict(size=18,
                                       color='grey'),
                             xref='paper', # container or paper
                             x=0.5,
                             y=0.9,
                             xanchor='center'
                            ),
                  showlegend=False,
                  font = dict(size = 10),
                  width=900,
                  height=700
                   )
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.25.2.min.js"></script>                <div id="a7b327c1-6843-448f-96a3-afa0a5b27ea4" class="plotly-graph-div" style="height:700px; width:900px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a7b327c1-6843-448f-96a3-afa0a5b27ea4")) {                    Plotly.newPlot(                        "a7b327c1-6843-448f-96a3-afa0a5b27ea4",                        [{"mode":"markers+text","text":"so","textposition":"top center","x":[-0.8934406042098999],"y":[-3.3047637939453125],"type":"scatter"},{"mode":"markers+text","text":"man","textposition":"top center","x":[-1.03794527053833],"y":[-5.120863914489746],"type":"scatter"},{"mode":"markers+text","text":"see","textposition":"top center","x":[-0.9100290536880493],"y":[-3.823899269104004],"type":"scatter"},{"mode":"markers+text","text":"more","textposition":"top center","x":[-0.9940311908721924],"y":[-3.545992851257324],"type":"scatter"},{"mode":"markers+text","text":"now","textposition":"top center","x":[-1.0927942991256714],"y":[-3.0032260417938232],"type":"scatter"},{"mode":"markers+text","text":"have","textposition":"top center","x":[-0.8503017425537109],"y":[-3.5738768577575684],"type":"scatter"},{"mode":"markers+text","text":"father","textposition":"top center","x":[-0.6888719797134399],"y":[-3.0274667739868164],"type":"scatter"},{"mode":"markers+text","text":"feel","textposition":"top center","x":[-1.038507342338562],"y":[-2.332554817199707],"type":"scatter"},{"mode":"markers+text","text":"say","textposition":"top center","x":[-1.0526342391967773],"y":[-2.6231417655944824],"type":"scatter"},{"mode":"markers+text","text":"day","textposition":"top center","x":[-1.3554308414459229],"y":[-3.7401678562164307],"type":"scatter"},{"mode":"markers+text","text":"friend","textposition":"top center","x":[-1.027772068977356],"y":[-3.366281032562256],"type":"scatter"},{"mode":"markers+text","text":"only","textposition":"top center","x":[-0.8227845430374146],"y":[-2.720322847366333],"type":"scatter"},{"mode":"markers+text","text":"life","textposition":"top center","x":[-1.0247564315795898],"y":[-3.0617151260375977],"type":"scatter"},{"mode":"markers+text","text":"eye","textposition":"top center","x":[-0.8023603558540344],"y":[-4.118092060089111],"type":"scatter"},{"mode":"markers+text","text":"find","textposition":"top center","x":[-1.2341047525405884],"y":[-3.072627067565918],"type":"scatter"},{"mode":"markers+text","text":"make","textposition":"top center","x":[-0.6447029709815979],"y":[-3.080822706222534],"type":"scatter"},{"mode":"markers+text","text":"time","textposition":"top center","x":[-0.997186541557312],"y":[-4.650097846984863],"type":"scatter"},{"mode":"markers+text","text":"then","textposition":"top center","x":[-1.109686255455017],"y":[-2.7524805068969727],"type":"scatter"},{"mode":"markers+text","text":"first","textposition":"top center","x":[-0.8594047427177429],"y":[-2.7658660411834717],"type":"scatter"},{"mode":"markers+text","text":"own","textposition":"top center","x":[-0.6433809995651245],"y":[-4.323747634887695],"type":"scatter"},{"mode":"markers+text","text":"place","textposition":"top center","x":[-1.0166456699371338],"y":[-5.074381351470947],"type":"scatter"},{"mode":"markers+text","text":"know","textposition":"top center","x":[-0.7975945472717285],"y":[-3.6863765716552734],"type":"scatter"},{"mode":"markers+text","text":"great","textposition":"top center","x":[-1.1107895374298096],"y":[-2.8542330265045166],"type":"scatter"},{"mode":"markers+text","text":"feeling","textposition":"top center","x":[-1.0664604902267456],"y":[-3.507237195968628],"type":"scatter"},{"mode":"markers+text","text":"take","textposition":"top center","x":[-1.0818638801574707],"y":[-4.413270473480225],"type":"scatter"},{"mode":"markers+text","text":"other","textposition":"top center","x":[-0.77467 ...
